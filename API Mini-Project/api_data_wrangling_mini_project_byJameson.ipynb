# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = '5CdZ-xxygHEfBnk1Cg5C'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
import textwrap
import json

base_url = ''
url = "https://www.quandl.com/api/v3/datasets/WIKI/FB/data.json?api_key=" + API_KEY
print(url + '\n')

response = requests.get(url)
# json_data = textwrap.fill(str(response.json()), width=130)
parsed = json.loads(response.text)

print(json.dumps(parsed, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#                 "2013-09-16",
#                 44.85,
#                 44.94,
#                 42.43,
#                 42.51,
#                 70424200.0,
#                 0.0,
#                 1.0,
#                 44.85,
#                 44.94,
#                 42.43,
#                 42.51,
#                 70424200.0
#             ],
#             [
#                 "2013-09-13",
#                 45.04,
#                 45.08,
#                 43.93,
#                 44.31,
#                 52765300.0,
#                 0.0,
#                 1.0,
#                 45.04,
#                 45.08,
#                 43.93,
#                 44.31,
#                 52765300.0
#             ],
#             [
#                 "2013-09-12",
#                 45.53,
#                 45.62,
#                 44.65,
#                 44.75,
#                 68072300.0,
#                 0.0,
# ...

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
#Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).

#https://www.quandl.com/api/v3/datasets/FSE/AFX_X/data.json?&api_key=5CdZ-xxygHEfBnk1Cg5C&start_date=2017-01-01&end_date=2017-12-31
#
base_url = 'https://www.quandl.com/api/v3/datasets/'
datatables = 'FSE'
ticker = 'AFX_X'
start_date = '2017-01-01'
end_date = '2017-12-31'
API_KEY = '5CdZ-xxygHEfBnk1Cg5C'

full_url = base_url + datatables + '/' + ticker + '/data.json?' + 'start_date=' + start_date + '&end_date=' + end_date +'&api_key=' + API_KEY

print(full_url + '\n')

response = requests.get(full_url)
# json_data = textwrap.fill(str(response.json()), width=130)
parsed = json.loads(response.text)

print(json.dumps(parsed, indent=4))
# Out:
# https://www.quandl.com/api/v3/datasets/FSE/AFX_X/data.json?start_date=2017-01-01&end_date=2017-12-31&api_key=5CdZ-xxygHEfBnk1Cg5C
#
# {
#     "dataset_data": {
#         "limit": null,
#         "transform": null,
#         "column_index": null,
#         "column_names": [
#             "Date",
#             "Open",
#             "High",
#             "Low",
#             "Close",
#             "Change",
#             "Traded Volume",
#             "Turnover",
#             "Last Price of the Day",
#             "Daily Traded Units",
#             "Daily Turnover"
#         ],
#         "start_date": "2017-01-01",
#         "end_date": "2017-12-31",
#         "frequency": "daily",
#         "data": [
#             [
#                 "2017-12-29",
#                 51.76,
#                 51.94,
#                 51.45,
#                 51.76,
#                 null,
#                 34640.0,
#                 1792304.0,
#                 null,
#                 null,
# ...

# %%
#Convert the returned JSON object into a Python dictionary.
stock_2017_dict = dict(parsed)
print(stock_2017_dict)
# Out:
# {'dataset_data': {'limit': None, 'transform': None, 'column_index': None, 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'start_date': '2017-01-01', 'end_date': '2017-12-31', 'frequency': 'daily', 'data': [['2017-12-29', 51.76, 51.94, 51.45, 51.76, None, 34640.0, 1792304.0, None, None, None], ['2017-12-28', 51.65, 51.82, 51.43, 51.6, None, 40660.0, 2099024.0, None, None, None], ['2017-12-27', 51.45, 51.89, 50.76, 51.82, None, 57452.0, 2957018.0, None, None, None], ['2017-12-22', 51.05, 51.5, 50.92, 51.32, None, 71165.0, 3641949.0, None, None, None], ['2017-12-21', 51.16, 51.52, 50.9, 51.4, None, 120649.0, 6179433.0, None, None, None], ['2017-12-20', 51.88, 52.04, 51.2, 51.27, None, 50587.0, 2610258.0, None, None, None], ['2017-12-19', 52.73, 52.73, 51.07, 51.66, None, 137313.0, 7102361.0, None, None, None], ['2017-12-18', 52.37, 52.75, 51.61, 52.62, None, 129733.0, 67704
# ...

# %%
#Calculate what the highest and lowest opening prices were for the stock in this period.
import pandas as pd
stock_2017_df = pd.DataFrame(columns = stock_2017_dict['dataset_data']['column_names'], data = stock_2017_dict['dataset_data']['data'])
stock_2017_df.index = stock_2017_df['Date']
pd.options.display.max_columns = 30
print(stock_2017_df.head())
print('\n')
print('Highest Opening Prices:')
print(stock_2017_df['Open'].max())
print('Lowest Opening Prices:')
print(stock_2017_df['Open'].min())
# Out:
#                   Date   Open   High    Low  Close  Change  Traded Volume  \
# Date
# 2017-12-29  2017-12-29  51.76  51.94  51.45  51.76     NaN        34640.0
# 2017-12-28  2017-12-28  51.65  51.82  51.43  51.60     NaN        40660.0
# 2017-12-27  2017-12-27  51.45  51.89  50.76  51.82     NaN        57452.0
# 2017-12-22  2017-12-22  51.05  51.50  50.92  51.32     NaN        71165.0
# 2017-12-21  2017-12-21  51.16  51.52  50.90  51.40     NaN       120649.0
#
#              Turnover Last Price of the Day Daily Traded Units Daily Turnover
# Date
# 2017-12-29  1792304.0                  None               None           None
# 2017-12-28  2099024.0                  None               None           None
# 2017-12-27  2957018.0                  None               None           None
# 2017-12-22  3641949.0                  None               None           None
# 2017-12-21  6179433.0                  None               None           None
#
#
# Highest Opening Prices:
# 53.11
# ...

# %%
#What was the largest change in any one day (based on High and Low price)?
change = stock_2017_df['High'] - stock_2017_df['Low']
print(change.head())
print('\n')
print('Largest change in any one day(based on High and Low price):')
print(change.max())
# Out:
# Date
# 2017-12-29    0.49
# 2017-12-28    0.39
# 2017-12-27    1.13
# 2017-12-22    0.58
# 2017-12-21    0.62
# dtype: float64
#
#
# Largest change in any one day:
# 2.8100000000000023

# %%
from dateutil import parser

#What was the largest change between any two days (based on Closing Price)?
stock_2017_df.index = pd.DatetimeIndex(stock_2017_df['Date'])
#resampled.transform(lambda x: (x - x.mean()) / x.std())
two_day_max_df = stock_2017_df['Close'].resample('2D').max()
two_day_min_df = stock_2017_df['Close'].resample('2D').min()
print(two_day_max_df)
print('\n')
print(two_day_min_df)
print('\n')
two_day_difference = two_day_max_df - two_day_min_df
print('The largest change between any two days(based on Closing Price):')
print(two_day_difference.max())
# Out:
# Date
# 2017-01-02    35.80
# 2017-01-04    35.19
# 2017-01-06    35.04
# 2017-01-08    34.67
# 2017-01-10    35.42
#               ...
# 2017-12-20    51.40
# 2017-12-22    51.32
# 2017-12-24      NaN
# 2017-12-26    51.82
# 2017-12-28    51.76
# Freq: 2D, Name: Close, Length: 181, dtype: float64
#
#
# Date
# 2017-01-02    35.48
# 2017-01-04    35.06
# 2017-01-06    35.04
# 2017-01-08    34.67
# 2017-01-10    34.91
#               ...
# 2017-12-20    51.27
# 2017-12-22    51.32
# 2017-12-24      NaN
# 2017-12-26    51.82
# 2017-12-28    51.60
# Freq: 2D, Name: Close, Length: 181, dtype: float64
#
#
# The largest change between any two days(based on Closing Price):
# 2.559999999999995

# %%
#What was the average daily trading volume during this year?
print('Average daily trading volume during this year:')
print(stock_2017_df['Traded Volume'].mean())
# print(stock_2017_df['Traded Volume'].resample('Y').mean())
# Out:
# Average daily trading volume during this year:
# 89124.33725490196

# %%
#(Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)
print('The median trading volume during this year:')
print(stock_2017_df['Traded Volume'].median())
# Out:
# The median trading volume during this year:
# 76286.0
